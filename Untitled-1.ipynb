# %%
from tvDatafeed import TvDatafeed, Interval
import pandas as pd 
# Initialize TVDataFeed (make sure you have your TradingView credentials set up)
tv = TvDatafeed()
# Fetch historical data for Nifty 50 on NSE exchange
#BANKNIFTY 27 JAN 2026 CALL 58400  ==> BANKNIFTY260127C58400  BANKNIFTY260120C59500
data = tv.get_hist(symbol="BANKNIFTY260120C59500", exchange="NSE", interval=Interval.in_1_minute, n_bars=100,fut_contract=None)
# Convert the data to a pandas DataFrame for easier manipulation    
df = pd.DataFrame(data)
# Display the first few rows of the DataFrame       
print(df.head())

#Now fetching data for NIFTY CALL OPTION
#NIFTY 26 JAN 2026 CALL 25450  ==> NIFTY260120C25450
data = tv.get_hist(symbol="NIFTY260120C25450", exchange="NSE", interval=Interval.in_1_minute, n_bars=100,fut_contract=None)
# Convert the data to a pandas DataFrame for easier manipulation    
df = pd.DataFrame(data)
# Display the first few rows of the DataFrame       
print(df.head())

#Now fetching data for NIFTY SPOT
data = tv.get_hist(symbol="NIFTY", exchange="NSE", interval=Interval.in_1_minute, n_bars=100,fut_contract=None)
# Convert the data to a pandas DataFrame for easier manipulation    
df = pd.DataFrame(data)
# Display the first few rows of the DataFrame       
print(df.head())


#Now fetching data for BANKNIFTY SPOT
data = tv.get_hist(symbol="BANKNIFTY", exchange="NSE", interval=Interval.in_1_minute, n_bars=100,fut_contract=None)
# Convert the data to a pandas DataFrame for easier manipulation    
df = pd.DataFrame(data)
# Display the first few rows of the DataFrame       
print(df.head())    


#Feteching NIFTY FUTURE DATA
#fut_contract : int, optional
#None for cash, 1 for continuous current contract in front, 2 for continuous next contract in front . Defaults to None.


data = tv.get_hist(symbol="NIFTY", exchange="NSE", interval=Interval.in_1_minute, n_bars=100,fut_contract=1) #1 means current month future
# Convert the data to a pandas DataFrame for easier manipulation
# Out:
# Error obtaining cookies: Chrome cookies from version v130 can be decrypted only when running as admin due to appbound encryption!
#
# Location:
#     rookie-rs\src\browser\chromium.rs:52:9
#  TOKEN : None
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# Empty DataFrame
# Columns: []
# Index: []
#                                     symbol  open  high   low  close     volume
# datetime
# 2026-01-20 13:50:00  NSE:NIFTY260120C25450  7.45  8.00  7.40    7.4  3045640.0
# 2026-01-20 13:51:00  NSE:NIFTY260120C25450  7.50  8.15  7.50    7.6  3492190.0
# 2026-01-20 13:52:00  NSE:NIFTY260120C25450  7.75  8.45  7.75    8.4  3813160.0
# 2026-01-20 13:53:00  NSE:NIFTY260120C25450  8.25  8.70  7.95    8.3  3592420.0
# 2026-01-20 13:54:00  NSE:NIFTY260120C25450  8.40  8.45  7.60    7.7  2918370.0
#                         symbol      open      high       low     close  \
# datetime
# 2026-01-20 13:50:00  NSE:NIFTY  25365.00  25368.05  25360.25  25362.95
# 2026-01-20 13:51:00  NSE:NIFTY  25365.20  25370.80  25362.75  25366.75
# 2026-01-20 13:52:00  NSE:NIFTY  25368.70  25372.15  25365.50  25369.20
# 2026-01-20 13:53:00  NSE:NIFTY  25370.65  25376.00  25367.90  25372.10
# 2026-01-20 13:54:00  NSE:NIFTY  25373.90  25374.65  25367.60  25369.40
#
#                         volume
# datetime
# 2026-01-20 13:50:00  1156039.0
# 2026-01-20 13:51:00   606431.0
# 2026-01-20 13:52:00   796478.0
# 2026-01-20 13:53:00   509059.0
# 2026-01-20 13:54:00   568040.0
#                             symbol      open      high       low     close  \
# datetime
# 2026-01-20 13:50:00  NSE:BANKNIFTY  59551.80  59556.75  59541.05  59545.00
# 2026-01-20 13:51:00  NSE:BANKNIFTY  59536.95  59560.60  59536.95  59545.45
# 2026-01-20 13:52:00  NSE:BANKNIFTY  59544.30  59563.90  59541.55  59557.20
# 2026-01-20 13:53:00  NSE:BANKNIFTY  59560.05  59584.65  59552.45  59580.30
# 2026-01-20 13:54:00  NSE:BANKNIFTY  59579.35  59584.35  59562.00  59574.25
#
#                         volume
# datetime
# 2026-01-20 13:50:00   358761.0
# 2026-01-20 13:51:00   363279.0
# 2026-01-20 13:52:00   289628.0
# 2026-01-20 13:53:00   560986.0
# 2026-01-20 13:54:00  1150794.0

# %%
import data_sourcing.trendlyne_client as trendlyne_client
client = trendlyne_client.TrendlyneClient()


client.get_stock_id_for_symbol("NIFTY")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import data_sourcing.trendlyne_client as trendlyne_client
#       2 client = trendlyne_client.TrendlyneClient()
#       5 client.get_stock_id_for_symbol("NIFTY")
#
# ModuleNotFoundError: No module named 'data_sourcing'

# %%
client.get_stock_id_for_symbol("BANKNIFTY")
# Out:
# 1898
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# NIFTY 50 EXPIRY DATES
# 13-Jan-2026, 20-Jan-2026, 27-Jan-2026, 03-Feb-2026, 10-Feb-2026, 24-Feb-2026, 30-Mar-2026, 30-Jun-2026, 29-Sep-2026, 29-Dec-2026, 29-Jun-2027
# {
#     "expiresDts": [
#         "02-JAN-2025",
#         "09-JAN-2025",
#         "16-JAN-2025",
#         "23-JAN-2025",
#         "30-JAN-2025",
#         "06-FEB-2025",
#         "13-FEB-2025",
#         "20-FEB-2025",
#         "27-FEB-2025",
#         "06-MAR-2025",
#         "13-MAR-2025",
#         "20-MAR-2025",
#         "27-MAR-2025",
#         "03-APR-2025",
#         "09-APR-2025",
#         "17-APR-2025",
#         "24-APR-2025",
#         "30-APR-2025",
#         "08-MAY-2025",
#         "15-MAY-2025",
#         "22-MAY-2025",
#         "29-MAY-2025",
#         "05-JUN-2025",
#         "12-JUN-2025",
#         "19-JUN-2025",
#         "26-JUN-2025",
#         "03-JUL-2025",
#         "10-JUL-2025",
#         "17-JUL-2025",
#         "24-JUL-2025",
#         "31-JUL-2025",
#         "07-AUG-2025",
#         "14-AUG-2025",
#         "21-AUG-2025",
#         "28-AUG-2025",
#         "02-SEP-2025",
#         "09-SEP-2025",
#         "16-SEP-2025",
#         "23-SEP-2025",
#         "25-SEP-2025",
#         "30-SEP-2025",
#         "07-OCT-2025",
#         "14-OCT-2025",
#         "20-OCT-2025",
#         "28-OCT-2025",
#         "04-NOV-2025",
#         "11-NOV-2025",
#         "18-NOV-2025",
#         "25-NOV-2025",
#         "02-DEC-2025",
#         "09-DEC-2025",
#         "16-DEC-2025",
#         "23-DEC-2025",
#         "24-DEC-2025",
#         "30-DEC-2025"
#     ]
# }

# %% [markdown]
# BN EXPIRT

# %% [markdown]
# {
#     "expiresDts": [
#         "27-JAN-2026",
#         "24-FEB-2026",
#         "26-MAR-2026",
#         "30-MAR-2026",
#         "31-MAR-2026",
#         "30-JUN-2026",
#         "29-SEP-2026",
#         "29-DEC-2026"
#     ]
# }
